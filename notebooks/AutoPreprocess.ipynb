# %%
import SimpleITK as sitk
import os, glob
from os.path import dirname, join
from pprint import pprint

import pydicom
from pydicom.data import get_testdata_files
from pydicom.filereader import read_dicomdir

# %%
def add_dot(s):
    ls = s.split(" ")
    ls[0] = ls[0] + "."
    ls = " ".join(ls)
    return ls

# %%
kw = {
    't1': {
            'planes': ['ax', 'tra'],
            'neg': ['sag', 'cor', 'mprage'],
            'ops': ['pre', 'post', 'pg'],
            'contrast': ['gad', 'gd']
        },
    't2': {
        'planes': ['ax', 'tra'],
        'neg': ['sag', 'cor', 'mprage'],
        'ops': ['blade', 'flair'],
        'contrast': ['dark fluid', 'dark', 'fluid', 'fs', 'dark-fluid']
    }
}

# %%
def create_perms(ls, addDot=False):
    
    if addDot:
        ls = [x.lower() for x in ls] + \
                  [x.upper() for x in ls] + \
                  [x.title() for x in ls] + \
                  [add_dot(x).lower() for x in ls] + \
                  [add_dot(x).upper() for x in ls] + \
                  [add_dot(x).title() for x in ls]
    else:
        ls = [x.lower() for x in ls] + \
                  [x.upper() for x in ls] + \
                  [x.title() for x in ls]
        
    return ls

# %%
create_perms(['t1'])
# Out:
# ['t1', 'T1', 'T1']

# %%
def match_rule_t1(ser_desc, kw, reader=None, debug=False):
    
    seq = 't1'
    main_seq_key_name = ""
    # get plane permutations
    plane_perm = create_perms(kw[seq]['planes'], True)
    
    neg = create_perms(kw[seq]['neg'], True)
    
    # first find if there are any negative keywords present in this string
    for ne_kw in neg:
        if ne_kw in ser_desc:
            if debug:
                print('Found negative keyword {} in {}'.format(ne_kw, ser_desc))
            return {-1: 'invalid keyword'}
    
    # first find the plane
    f_plane = False
    for pl_kw in plane_perm:
        if f_plane == False and pl_kw in ser_desc:
            if debug:
                print('Found plane {} in {}'.format(pl_kw, ser_desc))
            f_plane = True
            break

    # get sequence permutations
    seq_perm = create_perms([seq])
    
    # find sequence
    f_seq = False
    for se_kw in seq_perm:
        if f_seq == False and se_kw in ser_desc:
            if debug:
                print('Found seq {} in {}'.format(se_kw, ser_desc))
            f_seq = True
            main_seq_key_name += "{}".format(se_kw.upper())
            break

    if not f_seq:
        return {-1: 'Cannot find sequence name, cannot assume sequence safely'}
    
    # find ops (pre, post, pg)
    
    ops_perm = create_perms(kw[seq]['ops'])
    
    f_op = False
    for op_kw in ops_perm:
        if f_op == False and op_kw in ser_desc:
            if debug:
                print('Found op {} in {}'.format(op_kw, ser_desc))
            f_op = op_kw.lower()
            if f_op == 'post' or f_op == 'pg' or f_op == False:
                # there's no pre or post, but there is GAD, assume its CE
                if reader is not None:
                    assert reader.GetMetaData(0, "0018|0010") != "", "Something is wrong, no contrast agent defined in DICOM!"
                main_seq_key_name += "CE"
            break
            
    # find contrast
    
    co_perm = create_perms(kw[seq]['contrast'])
    
    f_co = False
    for co_kw in co_perm:
        if co_kw in ser_desc:
            if debug:
                print('Found contrast {} in {}'.format(co_kw, ser_desc))
            if 'CE' not in main_seq_key_name and f_op != 'pre':
                main_seq_key_name += "CE"
            f_co = True
            break
            
    return main_seq_key_name

# %%
def match_rule_t2(ser_desc, kw, reader=None, debug=False):
    
    seq = 't2'
    main_seq_key_name = ""
    # get plane permutations
    plane_perm = create_perms(kw[seq]['planes'], True)
    
    neg = create_perms(kw[seq]['neg'], True)
    
    # first find if there are any negative keywords present in this string
    for ne_kw in neg:
        if ne_kw in ser_desc:
            if debug:
                print('Found negative keyword {} in {}'.format(ne_kw, ser_desc))
            return {-1: 'invalid keyword'}
    
    # first find the plane
    f_plane = False
    for pl_kw in plane_perm:
        if f_plane == False and pl_kw in ser_desc:
            if debug:
                print('Found plane {} in {}'.format(pl_kw, ser_desc))
            f_plane = True
            break

    # get sequence permutations
    seq_perm = create_perms([seq])
    
    # find sequence
    f_seq = False
    for se_kw in seq_perm:
        if f_seq == False and se_kw in ser_desc:
            if debug:
                print('Found seq {} in {}'.format(se_kw, ser_desc))
            f_seq = True
            main_seq_key_name += "{}".format(se_kw.upper())
            break

    if not f_seq:
        return {-1: 'Cannot find sequence name, cannot assume sequence safely'}
    
    # find ops (blade, flair)
    
    ops_perm = create_perms(kw[seq]['ops'])
    
    f_op = False
    for op_kw in ops_perm:
        if f_op == False and op_kw in ser_desc:
            if debug:
                print('Found op {} in {}'.format(op_kw, ser_desc))
            f_op = op_kw.lower()
            if f_op == 'flair':
                # there's no pre or post, but there is GAD, assume its CE
                main_seq_key_name += "FLAIR"
            break
            
    # find contrast
    
    co_perm = create_perms(kw[seq]['contrast'])
    
    f_co = False
    for co_kw in co_perm:
        if co_kw in ser_desc and not f_co:
            if debug:
                print('Found contrast {} in {}'.format(co_kw, ser_desc))
            if 'FLAIR' not in main_seq_key_name:
                main_seq_key_name += "FLAIR"
            f_co = True
            break
            
    return main_seq_key_name

# %%
test_str = ["Ax. T1 SE Pre gad",
            "Ax. T1 SE Post gad",
           "Ax T1 Pre",
           "Ax T1",
           'ax t1',
            'AX. T1 SE PG',
           'Ax. T1 GAD', 
           "SAG. T1 TURBO DARK FLUID",
           "Cor T1",
            "Ax pre gad",
            "ax T1 MPRAGE PG",
            "Ax T2",
            "Ax T2 DARK FS"
           ]
neg_test_str = []

# %%
for tstr in test_str:
    print(tstr, " - ", match_rule_t1(tstr, kw, debug=False))
    print('')
# Out:
# Ax. T1 SE Pre gad  -  T1FLAIR
#
# Ax. T1 SE Post gad  -  T1FLAIR
#
# Ax T1 Pre  -  T1
#
# Ax T1  -  T1
#
# ax t1  -  T1
#
# AX. T1 SE PG  -  T1
#
# Ax. T1 GAD  -  T1FLAIR
#
# SAG. T1 TURBO DARK FLUID  -  {-1: 'invalid keyword'}
#
# Cor T1  -  {-1: 'invalid keyword'}
#
# Ax pre gad  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# ax T1 MPRAGE PG  -  {-1: 'invalid keyword'}
#
# Ax T2  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Ax T2 DARK FS  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}

# %%
for tstr in test_str:
    print(tstr, " - ", match_rule_t2(tstr, kw, debug=True))
    print('')
# Out:
# Found plane Ax in Ax. T1 SE Pre gad
# Ax. T1 SE Pre gad  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane Ax in Ax. T1 SE Post gad
# Ax. T1 SE Post gad  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane Ax in Ax T1 Pre
# Ax T1 Pre  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane Ax in Ax T1
# Ax T1  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane ax in ax t1
# ax t1  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane AX in AX. T1 SE PG
# AX. T1 SE PG  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found plane Ax in Ax. T1 GAD
# Ax. T1 GAD  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found negative keyword SAG in SAG. T1 TURBO DARK FLUID
# SAG. T1 TURBO DARK FLUID  -  {-1: 'invalid keyword'}
#
# Found negative keyword Cor in Cor T1
# Cor T1  -  {-1: 'invalid keyword'}
#
# Found plane Ax in Ax pre gad
# Ax pre gad  -  {-1: 'Cannot find sequence name, cannot assume sequence safely'}
#
# Found negative keyword MPRAGE in ax T1 MPRAGE PG
# ax T1 MPRAGE PG  -  {-1: 'invalid keyword'}
#
# Found plane Ax in Ax T2
# Found seq T2 in Ax T2
# Ax T2  -  T2
#
# Found plane Ax in Ax T2 DARK FS
# Found seq T2 in Ax T2 DARK FS
# Found contrast DARK in Ax T2 DARK FS
# Ax T2 DARK FS  -  T2FLAIR

# %%
match_rule_t2("AX. T1 SE POST GAD", kw, debug=True)
# Out:
# Found plane AX in AX. T1 SE POST GAD
# {-1: 'Cannot find sequence name, cannot assume sequence safely'}

# %%
path = "/local-scratch2/VGH_Data/IMediaExport/DICOM"
tags = {"Patient Name": "0010|0010",
        "Patient ID": "0010|0020",
        "Series Description": "0008|103e",
        "Modality": "0008|0060",
        "Contrast Agent": "0018|0010"
       }
pat

# %%
path = "/local-scratch2/VGH_Data/Export_Anmol_May_21_10/IMediaExport/DICOM"
tags = {"Patient Name": "0010|0010",
        "Patient ID": "0010|0020",
        "Series Description": "0008|103e",
        "Modality": "0008|0060",
        "Contrast Agent": "0018|0010"
       }
pat_data = {}
patients = glob.glob(os.path.join(path, "*"))
for pat in patients:
    for curr_std in glob.glob(os.path.join(pat, "*")):
        for curr_series in glob.glob(os.path.join(curr_std, "*")):
            curr_series_obj = glob.glob(os.path.join(curr_series, "*"))[0]
            # print( "Reading Dicom directory:", curr_series_obj )
            reader = sitk.ImageSeriesReader()

            dicom_names = reader.GetGDCMSeriesFileNames( curr_series_obj )
            if dicom_names == ():
#                 print("Empty List {}".format(curr_series_obj))
                continue
            reader.SetFileNames(dicom_names)
            reader.MetaDataDictionaryArrayUpdateOn()
            reader.LoadPrivateTagsOn()
            try:
                image = reader.Execute()
            except RuntimeError as e:
                print(e)
                continue
            no_flag = False
            # print only if I find Ax T1 in the study
            ser_desc = reader.GetMetaData(0, "0008|103e")
            pat_id = reader.GetMetaData(0, tags['Patient ID'])
            if not (pat_id in pat_data.keys()):
                pat_data[pat_id] = {
                    'T1': None,
                    'T2': None,
                    'T1CE': None,
                    'T2FLAIR': None
                }
            
            match_str = match_rule_t1(ser_desc, kw, reader)
            if isinstance(match_str, dict):
                
                match_str = match_rule_t2(ser_desc, kw)
            
                if isinstance(match_str, dict):
                    print('Patient {} Cannot match = {}'.format(reader.GetMetaData(0, tags['Patient Name']),
                                                                               ser_desc))
                    continue
                else:
                    print("Matched Patient {}, SeriesDescription {} to {}".format(reader.GetMetaData(0, tags['Patient Name']),
                                                                                                 ser_desc, match_str))
            else:
                
                print("="*50)
                print("Matched Patient {}, SeriesDescription {} to {}".format(reader.GetMetaData(0, tags['Patient Name']),
                                                                                                 ser_desc, match_str))
                
            for ct, t in tags.items():
                try:
                    print(ct, ": ", reader.GetMetaData(0, t))
                except RuntimeError:
                    print('Key {} not present'.format(t))
                
            
            image = sitk.Resample(image, [240, 240, 155], 
                                  sitk.Transform(), 
                                  sitk.sitkBSpline, 
                                  image.GetOrigin(), 
                                  [1,1,1], 
                                  image.GetDirection(), 
                                  0.0, 
                                  image.GetPixelID())
            size = image.GetSize()
            pat_data[pat_id][match_str] = image
            
            # sitk.Show(image)
            # input()
            print( "Image size:", size[0], size[1], size[2] )
            print("-"*50)
            print("")
# Out:
# Patient KALIM^MOHAMMED^^^  Cannot match = localizer
# Patient KALIM^MOHAMMED^^^  Cannot match = SAG. T1 TURBO DARK FLUID
# Patient KALIM^MOHAMMED^^^  Cannot match = AX. DWI_TRACEW
# Patient KALIM^MOHAMMED^^^  Cannot match = AX. DWI_ADC
# Patient KALIM^MOHAMMED^^^  Cannot match = mIP_Images(SW)
# Patient KALIM^MOHAMMED^^^  Cannot match = Mag_Images
# Patient KALIM^MOHAMMED^^^  Cannot match = Pha_Images
# Patient KALIM^MOHAMMED^^^  Cannot match = SWI_Images
# Matched Patient KALIM^MOHAMMED^^^ , SeriesDescription TRA T2 BLADE to T2
# Patient ID :  04191134
# Series Description :  TRA T2 BLADE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  KALIM^MOHAMMED^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient KALIM^MOHAMMED^^^ , SeriesDescription Ax. T1 SE Pre gad  to T1
# Patient ID :  04191134
# Series Description :  Ax. T1 SE Pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  KALIM^MOHAMMED^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient KALIM^MOHAMMED^^^  Cannot match = Brainlab Ax. T1 MPRAGE post gad
# Matched Patient KALIM^MOHAMMED^^^ , SeriesDescription TRA T2 FS DARK FLUID BLADE to T2FLAIR
# Patient ID :  04191134
# Series Description :  TRA T2 FS DARK FLUID BLADE
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  KALIM^MOHAMMED^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient KALIM^MOHAMMED^^^ , SeriesDescription AX. T1 SE POST GAD to T1CE
# Patient ID :  04191134
# Series Description :  AX. T1 SE POST GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  KALIM^MOHAMMED^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient KALIM^MOHAMMED^^^  Cannot match = SAG. T1 SE POST GAD
# Patient KALIM^MOHAMMED^^^  Cannot match = COR. T1 SE POST GAD
# Patient KALIM^MOHAMMED^^^  Cannot match = B1000
# Patient KALIM^MOHAMMED^^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient JOHNNIE^Nikki^^^ Cannot match = localizer
# Patient JOHNNIE^Nikki^^^ Cannot match = SAG. T1 TURBO DARK FLUID
# Patient JOHNNIE^Nikki^^^ Cannot match = AX. DWI_TRACEW
# Patient JOHNNIE^Nikki^^^ Cannot match = AX. DWI_ADC
# Patient JOHNNIE^Nikki^^^ Cannot match = mIP_Images(SW)
# Patient JOHNNIE^Nikki^^^ Cannot match = Mag_Images
# Patient JOHNNIE^Nikki^^^ Cannot match = Pha_Images
# Patient JOHNNIE^Nikki^^^ Cannot match = SWI_Images
# Matched Patient JOHNNIE^Nikki^^^, SeriesDescription TRA T2 BLADE to T2
# Patient ID :  04269360
# Series Description :  TRA T2 BLADE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JOHNNIE^Nikki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient JOHNNIE^Nikki^^^, SeriesDescription Ax. T1 SE Pre gad  to T1
# Patient ID :  04269360
# Series Description :  Ax. T1 SE Pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JOHNNIE^Nikki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient JOHNNIE^Nikki^^^, SeriesDescription TRA T2 FS DARK FLUID BLADE to T2FLAIR
# Patient ID :  04269360
# Series Description :  TRA T2 FS DARK FLUID BLADE
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JOHNNIE^Nikki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient JOHNNIE^Nikki^^^, SeriesDescription AX. T1 SE POST GAD to T1CE
# Patient ID :  04269360
# Series Description :  AX. T1 SE POST GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JOHNNIE^Nikki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient JOHNNIE^Nikki^^^ Cannot match = SAG. T1 SE POST GAD
# Patient JOHNNIE^Nikki^^^ Cannot match = COR. T1 SE POST GAD
# Patient JOHNNIE^Nikki^^^ Cannot match = B1000
# Patient JOHNNIE^Nikki^^^ Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient JOHNNIE^Nikki^^^ Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient JHAJ^Ranbir^S^^  Cannot match = localizer
# Patient JHAJ^Ranbir^S^^  Cannot match = SAG. T1 TURBO DARK FLUID
# Patient JHAJ^Ranbir^S^^  Cannot match = AX. DWI_TRACEW
# Patient JHAJ^Ranbir^S^^  Cannot match = AX. DWI_ADC
# Matched Patient JHAJ^Ranbir^S^^ , SeriesDescription AX. T2 TURBO DARK FLUID FS to T2FLAIR
# Patient ID :  04264171
# Series Description :  AX. T2 TURBO DARK FLUID FS
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JHAJ^Ranbir^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient JHAJ^Ranbir^S^^ , SeriesDescription AX. TSE T2 to T2
# Patient ID :  04264171
# Series Description :  AX. TSE T2
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JHAJ^Ranbir^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient JHAJ^Ranbir^S^^  Cannot match = mIP_Images(SW)
# Patient JHAJ^Ranbir^S^^  Cannot match = Mag_Images
# Patient JHAJ^Ranbir^S^^  Cannot match = Pha_Images
# Patient JHAJ^Ranbir^S^^  Cannot match = SWI_Images
# ==================================================
# Matched Patient JHAJ^Ranbir^S^^ , SeriesDescription Ax. T1 SE pre gad  to T1
# Patient ID :  04264171
# Series Description :  Ax. T1 SE pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JHAJ^Ranbir^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient JHAJ^Ranbir^S^^ , SeriesDescription AX. T1 SE PG to T1CE
# Patient ID :  04264171
# Series Description :  AX. T1 SE PG
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JHAJ^Ranbir^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient JHAJ^Ranbir^S^^  Cannot match = COR. T1 SE PG
# Patient JHAJ^Ranbir^S^^  Cannot match = SAG. T1 SE PG
# Patient JHAJ^Ranbir^S^^  Cannot match = TRA T1 MPRAGE PG
# Patient JHAJ^Ranbir^S^^  Cannot match = B1000
# Patient JHAJ^Ranbir^S^^  Cannot match = SUB MPRAGE
# Patient JHAJ^Ranbir^S^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient JAFAR^Mohammad^S^^ Cannot match = MHROUT/MGHMR HD/ROUTINE
# Patient JAFAR^Mohammad^S^^ Cannot match = localizer
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DWI_TRACEW
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DWI_ADC
# Patient JAFAR^Mohammad^S^^ Cannot match = mIP_Images(SW)
# Patient JAFAR^Mohammad^S^^ Cannot match = Mag_Images
# Patient JAFAR^Mohammad^S^^ Cannot match = Pha_Images
# Patient JAFAR^Mohammad^S^^ Cannot match = SWI_Images
# Matched Patient JAFAR^Mohammad^S^^, SeriesDescription AX. T2 TURBO DARK FLUID FS to T2FLAIR
# Patient ID :  03239421
# Series Description :  AX. T2 TURBO DARK FLUID FS
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JAFAR^Mohammad^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient JAFAR^Mohammad^S^^, SeriesDescription AX. T1 SE PRE GAD  to T1
# Patient ID :  03239421
# Series Description :  AX. T1 SE PRE GAD
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  JAFAR^Mohammad^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient JAFAR^Mohammad^S^^, SeriesDescription AX. TSE T2 to T2
# Patient ID :  03239421
# Series Description :  AX. TSE T2
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JAFAR^Mohammad^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient JAFAR^Mohammad^S^^, SeriesDescription AX. T1 SE POST GAD to T1CE
# Patient ID :  03239421
# Series Description :  AX. T1 SE POST GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JAFAR^Mohammad^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient JAFAR^Mohammad^S^^ Cannot match = SAG. T1 SE POST GAD
# Patient JAFAR^Mohammad^S^^ Cannot match = COR. T1 SE POST GAD
# Matched Patient JAFAR^Mohammad^S^^, SeriesDescription TRA T2 BLADE to T2
# Patient ID :  03239421
# Series Description :  TRA T2 BLADE
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  JAFAR^Mohammad^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient JAFAR^Mohammad^S^^ Cannot match = localizer
# Patient JAFAR^Mohammad^S^^ Cannot match = Brainlab Ax. T1 MPRAGE post gad
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DTI 20 DIRECTIONS
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DTI 20 DIRECTIONS_ADC
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DTI 20 DIRECTIONS_TRACEW
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DTI 20 DIRECTIONS_FA
# Patient JAFAR^Mohammad^S^^ Cannot match = AX. DTI 20 DIRECTIONS_ColFA
# Patient JAFAR^Mohammad^S^^ Cannot match = SAG. T1 TURBO DARK FLUID_FIL_1
# Patient JAFAR^Mohammad^S^^ Cannot match = B1000
# Patient HWANG^Leona^S^^  Cannot match = LOC
# Patient HWANG^Leona^S^^  Cannot match = SAG T1 FLAIR
# Patient HWANG^Leona^S^^  Cannot match = AX DWI_TRACEW
# Patient HWANG^Leona^S^^  Cannot match = AX DWI_ADC
# Patient HWANG^Leona^S^^  Cannot match = mIP_Images(SW)
# Patient HWANG^Leona^S^^  Cannot match = Mag_Images
# Patient HWANG^Leona^S^^  Cannot match = Pha_Images
# Patient HWANG^Leona^S^^  Cannot match = SWI_Images
# ==================================================
# Matched Patient HWANG^Leona^S^^ , SeriesDescription AX T1 PRE  to T1
# Patient ID :  03206504
# Series Description :  AX T1 PRE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HWANG^Leona^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HWANG^Leona^S^^  Cannot match = localizer
# Patient HWANG^Leona^S^^  Cannot match = AX. DTI 30 DIRECTIONS
# Patient HWANG^Leona^S^^  Cannot match = AX. DTI 30 DIRECTIONS_ADC
# Patient HWANG^Leona^S^^  Cannot match = AX. DTI 30 DIRECTIONS_TRACEW
# Patient HWANG^Leona^S^^  Cannot match = AX. DTI 30 DIRECTIONS_FA
# Patient HWANG^Leona^S^^  Cannot match = AX. DTI 30 DIRECTIONS_ColFA
# Matched Patient HWANG^Leona^S^^ , SeriesDescription AX T2 FLAIR FS to T2FLAIR
# Patient ID :  03206504
# Series Description :  AX T2 FLAIR FS
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HWANG^Leona^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HWANG^Leona^S^^  Cannot match = TRA T1 MPRAGE PG
# Matched Patient HWANG^Leona^S^^ , SeriesDescription AX T2  to T2
# Patient ID :  03206504
# Series Description :  AX T2
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  HWANG^Leona^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient HWANG^Leona^S^^ , SeriesDescription AX T1 GAD  to T1CE
# Patient ID :  03206504
# Series Description :  AX T1 GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  HWANG^Leona^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HWANG^Leona^S^^  Cannot match = SAG T1 GAD
# Patient HWANG^Leona^S^^  Cannot match = COR T1 GAD
# Patient HWANG^Leona^S^^  Cannot match = B1000
# Patient HWANG^Leona^S^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient HUSSEIN^Mahirul^N^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient HUSSEIN^Mahirul^N^^  Cannot match = localizer
# Patient HUSSEIN^Mahirul^N^^  Cannot match = SAG. T1 TURBO DARK FLUID
# Patient HUSSEIN^Mahirul^N^^  Cannot match = mIP_Images(SW)
# Patient HUSSEIN^Mahirul^N^^  Cannot match = Mag_Images
# Patient HUSSEIN^Mahirul^N^^  Cannot match = Pha_Images
# Patient HUSSEIN^Mahirul^N^^  Cannot match = SWI_Images
# Matched Patient HUSSEIN^Mahirul^N^^ , SeriesDescription AX. TSE T2 to T2
# Patient ID :  04065424
# Series Description :  AX. TSE T2
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HUSSEIN^Mahirul^N^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient HUSSEIN^Mahirul^N^^ , SeriesDescription AX. T2 TURBO DARK FLUID FS to T2FLAIR
# Patient ID :  04065424
# Series Description :  AX. T2 TURBO DARK FLUID FS
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HUSSEIN^Mahirul^N^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient HUSSEIN^Mahirul^N^^ , SeriesDescription Ax. T1 SE Pre gad  to T1
# Patient ID :  04065424
# Series Description :  Ax. T1 SE Pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HUSSEIN^Mahirul^N^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient HUSSEIN^Mahirul^N^^ , SeriesDescription AX. T1 SE POST GAD to T1CE
# Patient ID :  04065424
# Series Description :  AX. T1 SE POST GAD
# Contrast Agent :  with contrast
# Modality :  MR
# Patient Name :  HUSSEIN^Mahirul^N^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HUSSEIN^Mahirul^N^^  Cannot match = SAG. T1 SE POST GAD
# Patient HUSSEIN^Mahirul^N^^  Cannot match = COR. T1 SE POST GAD
# Patient HUSSEIN^Mahirul^N^^  Cannot match = Brainlab Ax. T1 MPRAGE post gad
# Patient HUSSEIN^Mahirul^N^^  Cannot match = AX. DTI 20 DIRECTIONS
# Patient HUSSEIN^Mahirul^N^^  Cannot match = AX. DTI 20 DIRECTIONS_ADC
# Patient HUSSEIN^Mahirul^N^^  Cannot match = AX. DTI 20 DIRECTIONS_TRACEW
# Patient HUSSEIN^Mahirul^N^^  Cannot match = AX. DTI 20 DIRECTIONS_FA
# Patient HUSSEIN^Mahirul^N^^  Cannot match = AX. DTI 20 DIRECTIONS_ColFA
# Patient HUSSEIN^Mahirul^N^^  Cannot match = Brainlab Ax. T1 MPRAGE post gad
# Patient HULL^Debora^D^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient HULL^Debora^D^^  Cannot match = localizer
# Patient HULL^Debora^D^^  Cannot match = SAG. T1 TURBO DARK FLUID
# Patient HULL^Debora^D^^  Cannot match = AX. DWI (if not doing DTI)_TRACEW
# Patient HULL^Debora^D^^  Cannot match = AX. DWI (if not doing DTI)_ADC
# Matched Patient HULL^Debora^D^^ , SeriesDescription AX. T2 TURBO DARK FLUID FS to T2FLAIR
# Patient ID :  04141753
# Series Description :  AX. T2 TURBO DARK FLUID FS
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HULL^Debora^D^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient HULL^Debora^D^^ , SeriesDescription AX. TSE T2 to T2
# Patient ID :  04141753
# Series Description :  AX. TSE T2
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HULL^Debora^D^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HULL^Debora^D^^  Cannot match = mIP_Images(SW)
# Patient HULL^Debora^D^^  Cannot match = Mag_Images
# Patient HULL^Debora^D^^  Cannot match = Pha_Images
# Patient HULL^Debora^D^^  Cannot match = SWI_Images
# ==================================================
# Matched Patient HULL^Debora^D^^ , SeriesDescription Ax. T1 SE Pre gad  to T1
# Patient ID :  04141753
# Series Description :  Ax. T1 SE Pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HULL^Debora^D^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HULL^Debora^D^^  Cannot match = PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = GBP_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = PBP_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = TTP_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = PERFUSION
# Patient HULL^Debora^D^^  Cannot match = RELCBV_LOCAL_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = RELCBF_LOCAL_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = RELMTT_LOCAL_PERFUSION_MoCo
# Patient HULL^Debora^D^^  Cannot match = RELCCBV_LOCAL_PERFUSION_MoCo
# ==================================================
# Matched Patient HULL^Debora^D^^ , SeriesDescription AX. T1 SE POST GAD to T1CE
# Patient ID :  04141753
# Series Description :  AX. T1 SE POST GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  HULL^Debora^D^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HULL^Debora^D^^  Cannot match = COR. T1 SE POST GAD
# Patient HULL^Debora^D^^  Cannot match = SAG. T1 SE POST GAD
# Patient HULL^Debora^D^^  Cannot match = B 1000
# Patient HULL^Debora^D^^  Cannot match = rCBV_RGB
# Patient HASHIMOTO^Masayuki^^^  Cannot match = localizer
# Patient HASHIMOTO^Masayuki^^^  Cannot match = SAG TI DARK-FLUID BLADE
# Patient HASHIMOTO^Masayuki^^^  Cannot match = localizer REF
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX DWI_TRACEW
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX DWI_ADC
# Matched Patient HASHIMOTO^Masayuki^^^ , SeriesDescription TRA T2 BLADE to T2
# Patient ID :  03614103
# Series Description :  TRA T2 BLADE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HASHIMOTO^Masayuki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient HASHIMOTO^Masayuki^^^ , SeriesDescription TRA T2 FS DARK-FLUID BLADE to T2FLAIR
# Patient ID :  03614103
# Series Description :  TRA T2 FS DARK-FLUID BLADE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HASHIMOTO^Masayuki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HASHIMOTO^Masayuki^^^  Cannot match = mIP_Images(SW)
# Patient HASHIMOTO^Masayuki^^^  Cannot match = Mag_Images
# Patient HASHIMOTO^Masayuki^^^  Cannot match = Pha_Images
# Patient HASHIMOTO^Masayuki^^^  Cannot match = SWI_Images
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX. DTI 30 DIRECTIONS
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX. DTI 30 DIRECTIONS_ADC
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX. DTI 30 DIRECTIONS_TRACEW
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX. DTI 30 DIRECTIONS_FA
# Patient HASHIMOTO^Masayuki^^^  Cannot match = AX. DTI 30 DIRECTIONS_ColFA
# ==================================================
# Matched Patient HASHIMOTO^Masayuki^^^ , SeriesDescription AX T1 SE pre gad to T1
# Patient ID :  03614103
# Series Description :  AX T1 SE pre gad
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HASHIMOTO^Masayuki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HASHIMOTO^Masayuki^^^  Cannot match = TRA T1 MPRAGE PG
# Patient HASHIMOTO^Masayuki^^^  Cannot match = SAG T1 SE PG
# ==================================================
# Matched Patient HASHIMOTO^Masayuki^^^ , SeriesDescription AX. T1 SE PG to T1CE
# Patient ID :  03614103
# Series Description :  AX. T1 SE PG
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  HASHIMOTO^Masayuki^^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HASHIMOTO^Masayuki^^^  Cannot match = COR T1 SE PG
# Patient HASHIMOTO^Masayuki^^^  Cannot match = B1000
# Patient HASHIMOTO^Masayuki^^^  Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = LOC
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = SAG T1 FLAIR
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = SAG SPACE FLAIR
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX DTI
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX DTI_ADC
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX DTI_TRACEW
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX DTI_FA
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX DTI_ColFA
# Matched Patient HAMILTON DUFFIEL^Blake^S^^, SeriesDescription AX T2  to T2
# Patient ID :  04226841
# Series Description :  AX T2
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HAMILTON DUFFIEL^Blake^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Matched Patient HAMILTON DUFFIEL^Blake^S^^, SeriesDescription AX T2 FLAIR  to T2FLAIR
# Patient ID :  04226841
# Series Description :  AX T2 FLAIR
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HAMILTON DUFFIEL^Blake^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient HAMILTON DUFFIEL^Blake^S^^, SeriesDescription AX T1 PRE  to T1
# Patient ID :  04226841
# Series Description :  AX T1 PRE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  HAMILTON DUFFIEL^Blake^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX MPRAGE GAD
# ==================================================
# Matched Patient HAMILTON DUFFIEL^Blake^S^^, SeriesDescription AX T1 GAD  to T1CE
# Patient ID :  04226841
# Series Description :  AX T1 GAD
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  HAMILTON DUFFIEL^Blake^S^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = AX MPRAGE GAD RPT
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = SAG T1 GAD
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = COR T1 FS GAD
# Patient HAMILTON DUFFIEL^Blake^S^^ Cannot match = MHDETL/MGHMR HD/DETAIL
# Patient GUILE^JOHN^GERRALD^^ Cannot match = SAG T1
# Matched Patient GUILE^JOHN^GERRALD^^, SeriesDescription AX TSE T2  to T2
# Patient ID :  9094519153
# Series Description :  AX TSE T2
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  GUILE^JOHN^GERRALD^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient GUILE^JOHN^GERRALD^^ Cannot match = AX FLAIR
# Patient GUILE^JOHN^GERRALD^^ Cannot match = DIFFUSION RESOLVE_TRACEW
# Patient GUILE^JOHN^GERRALD^^ Cannot match = DIFFUSION RESOLVE_ADC
# Patient GUILE^JOHN^GERRALD^^ Cannot match = mIP_Images(SW)
# Patient GUILE^JOHN^GERRALD^^ Cannot match = Mag_Images
# Patient GUILE^JOHN^GERRALD^^ Cannot match = SWI_Images
# ==================================================
# Matched Patient GUILE^JOHN^GERRALD^^, SeriesDescription AX T1 PRE  to T1
# Patient ID :  9094519153
# Series Description :  AX T1 PRE
# Key 0018|0010 not present
# Modality :  MR
# Patient Name :  GUILE^JOHN^GERRALD^^
# Image size: 240 240 155
# --------------------------------------------------
#
# ==================================================
# Matched Patient GUILE^JOHN^GERRALD^^, SeriesDescription AX T1 POST to T1CE
# Patient ID :  9094519153
# Series Description :  AX T1 POST
# Contrast Agent :  GADOVIST
# Modality :  MR
# Patient Name :  GUILE^JOHN^GERRALD^^
# Image size: 240 240 155
# --------------------------------------------------
#
# Patient GUILE^JOHN^GERRALD^^ Cannot match = COR T1 POST
# Patient GUILE^JOHN^GERRALD^^ Cannot match = SAG T1 POST
# Patient GUILE^JOHN^GERRALD^^ Cannot match = MRI Brain w/ + w/o Contrast HD

# %%
for k in pat_data.keys():
    for s in pat_data[k].keys():
        try:
            print(k, ":", "{}: ".format(s), pat_data[k][s].GetSize())
        except:
            continue
# Out:
# 04269360 : T2:  (240, 240, 155)
# 04269360 : T1:  (240, 240, 155)
# 04269360 : T1CE:  (240, 240, 155)
# 04269360 : T2FLAIR:  (240, 240, 155)
# 04191134 : T2:  (240, 240, 155)
# 04191134 : T1:  (240, 240, 155)
# 04191134 : T1CE:  (240, 240, 155)
# 04191134 : T2FLAIR:  (240, 240, 155)
# 03239421 : T2:  (240, 240, 155)
# 03239421 : T1:  (240, 240, 155)
# 03239421 : T1CE:  (240, 240, 155)
# 03239421 : T2FLAIR:  (240, 240, 155)
# 04065424 : T2:  (240, 240, 155)
# 04065424 : T1:  (240, 240, 155)
# 04065424 : T1CE:  (240, 240, 155)
# 04065424 : T2FLAIR:  (240, 240, 155)
# 9094519153 : T2:  (240, 240, 155)
# 9094519153 : T1:  (240, 240, 155)
# 9094519153 : T1CE:  (240, 240, 155)
# 03614103 : T2:  (240, 240, 155)
# 03614103 : T1:  (240, 240, 155)
# 03614103 : T1CE:  (240, 240, 155)
# 03614103 : T2FLAIR:  (240, 240, 155)
# 04264171 : T2:  (240, 240, 155)
# 04264171 : T1:  (240, 240, 155)
# 04264171 : T1CE:  (240, 240, 155)
# 04264171 : T2FLAIR:  (240, 240, 155)
# 04141753 : T2:  (240, 240, 155)
# 04141753 : T1:  (240, 240, 155)
# 04141753 : T1CE:  (240, 240, 155)
# 04141753 : T2FLAIR:  (240, 240, 155)
# 04226841 : T2:  (240, 240, 155)
# 04226841 : T1:  (240, 240, 155)
# 04226841 : T1CE:  (240, 240, 155)
# 04226841 : T2FLAIR:  (240, 240, 155)
# 03206504 : T2:  (240, 240, 155)
# 03206504 : T1:  (240, 240, 155)
# 03206504 : T1CE:  (240, 240, 155)
# 03206504 : T2FLAIR:  (240, 240, 155)

# %%
save_path = os.path.join(os.path.sep.join(path.split(os.path.sep)[0:-1]), "Cleaned_Data")

# %%
for k in pat_data.keys():
    pat_path = os.path.join(save_path, k)    
    for s in pat_data[k].keys():
        if pat_data[k][s] is not None:
            seq_path = os.path.join(pat_path, s)
            seq_name = os.path.join(seq_path, "Image_{}.nii.gz".format(s))
            if not os.path.exists(seq_path):
                os.makedirs(seq_path)

            sitk.WriteImage(pat_data[k][s], seq_name)
